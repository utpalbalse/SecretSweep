# %% [markdown]
# # Data Analysis
# Exploratory analysis of production dataset.

# %%
import os
import boto3

# Load credentials from environment
client = boto3.client('s3')
print(os.environ.get('AWS_ACCESS_KEY_ID'))
# Out:
# AKIAIOSFODNN7EXAMPLE1234

# %%
# List buckets
response = client.list_buckets()
print(response)
# Out:
# {'Buckets': [{'Name': 'prod-data', 'CreationDate': '2024-01-15'}]}
